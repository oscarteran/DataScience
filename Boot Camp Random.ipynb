# %% [markdown]
# Este notebook contiene los ejercicios de Numpy aplicado a la generación de números aleatorios:
#
#         Bootcamp of Data Science with Python [+250 exercises][A-Z]

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Ejercicio 1
data = random.normal(size = (4,5))
print(data)
# Out:
# [[1.19970507 2.54218318 3.47145664 1.96304154 4.83166885]
#  [6.59647979 4.81410458 6.74369879 1.64910972 1.30458585]
#  [8.66989261 8.91664398 1.4915268  3.99427084 3.99784698]
#  [4.72302783 3.52271088 6.30406571 9.75968236 2.38467968]]
# [[ 0.10545312  0.80691735 -1.44107841  0.78903146  2.3908374 ]
#  [-0.94166835  0.53262302 -1.91129467  0.39218628  0.79731287]
#  [ 0.19719702  1.17322115 -1.03598552  0.05112698  0.67325074]
#  [-1.04911868  0.62783187 -0.14668416 -0.23083201 -0.76674329]]

# %%
# Ejercicio 2
mu, sigma = 10, 3 # mean and standard deviation
s = np.random.normal(mu, sigma, (20,5))
datos = pd.DataFrame(s, columns = list('ABCDE'), index = range(1, s.shape[0]+1))
datos.head()
# Out:
#            A          B          C          D          E
# 1  10.502315  12.560150   7.683633   8.563484  14.120942
# 2  15.118209   3.624879  12.552209   6.512402  14.637323
# 3  10.278055  13.331263  14.189350   6.284483   7.989254
# 4   9.498045  12.827404   8.494203   6.815147   9.575275
# 5   9.548642   9.646473   8.627450  10.204464  16.654439

# %%
# Ejercicio 3
data = random.normal(size = 3000)
sns.displot(data, kind='kde')
plt.show()

sns.displot(data, kind = 'hist')
plt.show()

# %%
# Ejercicio 4
data1 = random.binomial(6, 0.5, 100)
data2 = random.binomial(2, 0.8, 1000)
print(data1)
# Out:
# [6 3 3 3 3 4 2 4 2 3 2 3 4 4 3 4 5 3 2 2 2 1 2 1 3 1 4 3 2 4 4 4 5 4 4 4 4
#  5 4 3 4 4 2 6 2 3 3 4 4 3 3 4 4 2 2 2 5 3 4 3 3 2 3 3 2 3 3 6 4 4 2 2 3 4
#  5 2 3 3 2 4 3 2 2 4 3 3 2 3 4 3 2 4 1 1 2 3 3 5 2 5]

# %%
# Ejercicio 5
sns.displot(data=data1, kind='kde')
plt.show()

sns.displot(data=data1, kind='hist')
plt.show()

# %%
# Ejercicio 6
data = random.uniform(size=(3,3))
print(data)
# Out:
# [[0.78681717 0.33138417 0.30621303]
#  [0.43699233 0.78987685 0.59962402]
#  [0.34111689 0.62189122 0.31608812]]

# %%
# Ejercicio 7
sns.displot(random.uniform(size=1000), kind='kde')
plt.plot()

sns.displot(random.uniform(size=1000))
plt.plot()
# Out:
# []

# %%
# Ejercicio 8
ar = np.zeros((30,5))
for i in range(30):
    for j in range(5):
        ar[i][j] = random.randint(-1000,3000)

ar2 = random.randint(-1000,3000, size=(30,5))

# %%
# Ejercicio 9
ar = random.randint(5, size=(30,5))

# %%
# Ejercicio 10
array = np.random.randint(low = 10, high = [100, 300, 50, 10000])
print(array)
# Out:
# [  29   71   40 6888]

# %%
# Ejercicio 11
ar = random.rand(10,5)
print(ar.mean())
print(ar.std())
print(np.median(ar))
# Out:
# 0.4758519484607105
# 0.2561002905623348
# 0.4559887699191455

# %%
# Ejercicio 11
ar = np.random.randn(30,3)
data = pd.DataFrame(data=data, columns=list('ABC'))

sns.displot(data, kind='kde')
sns.displot(data, kind='hist')
plt.show()

# %%
# Ejercicio 14
ex = np.random.standard_exponential(800)

# %%
# Ejercicio 15
po = np.random.poisson(5, size=(50,3))

# %%
# Ejercicio 16
po2 = np.random.poisson(3, 10000)
Ser1 = pd.Series(po2, name='Poisson')

sns.histplot(Ser1, kde = True)
plt.show()

# %%
# Ejercicio 17
ch = np.random.choice(['A','B','C','D'],size = 10)
ch
# Out:
# array(['B', 'D', 'B', 'B', 'A', 'A', 'A', 'D', 'D', 'C'], dtype='<U1')

# %% [markdown]
# Generate a DataFrame with 7 columns and 100 rows, with the following characteristics:
#
# column 'A' follows a standard normal distribution;
#
# column 'B' follows a uniform distribution;
#
# column 'C' follows a binomial distribution, with 6 attempts and probability of success 0.6;
#
# column 'D' follows a standard exponential distribution;
#
# column 'E' follows a Poisson distribution with a known number of occurrences equal to 10;
#
# column 'F' follows a normal distribution of mean 100 and standard deviation 15;
#
# the 'G' column has random integers between 50 and 3000.

# %%
# Ejercicio 18
data = {'A':np.random.normal(size=100), 'B':np.random.uniform(size=100), 'C':random.binomial(6, 0.6, 100),
        'D':np.random.standard_exponential(100), 'E':np.random.poisson(10, size=100),
        'F':np.random.normal(100, 5, 100), 'G':random.randint(50,3000, size=(100))}
df = pd.DataFrame(data)
df.head()
# Out:
#           A         B  C         D   E           F     G
# 0 -0.870694  0.656801  3  0.636661  13   90.749810  2071
# 1 -0.877154  0.415662  4  1.057311   7  105.881118   134
# 2  0.753760  0.128833  5  4.826605   9   98.648294  2970
# 3  1.423809  0.749658  4  1.856176  17  105.716641   456
# 4 -1.032469  0.766037  4  1.143120   7   97.477128  1314

# %%
# Ejercicio 19
chi = np.random.chisquare(3, size=(5,5))
print(chi)

chi2 = np.random.chisquare(2, size=(2000))
plt.figure(figsize=(10,8))
sns.histplot(chi2, kde = True, color = 'red')
plt.show()

exp = np.random.exponential(scale=5,size=(2,2))
print(exp)
# Out:
# [[7.51468893 0.40416463 2.33065404 2.0708462  2.27511665]
#  [0.70563235 1.78013436 6.18104542 1.33824357 1.78456409]
#  [9.0020398  2.47480415 3.43810236 7.83808978 0.48164746]
#  [4.039009   4.74388892 0.7762206  0.96929378 2.1173072 ]
#  [4.29099367 2.35398272 0.4679241  2.7902567  1.36781846]]
# [[ 4.32703364 12.45219255]
#  [21.2735409   0.31975315]]

# %%
# Ejercicio 20
ar = np.random.logistic(5, 0.9, 100)
print(ar)
# Out:
# [ 5.23948226  5.70298356  3.920991    5.00522202  5.12046715  7.20496636
#   5.96698017 11.60305681  6.36965671  6.9828905   3.58425655  4.50722239
#   3.54970189  6.49987658  4.95551454  5.46325448  5.22657548  7.94397467
#   4.66506203  1.95783418  5.10846973  7.0721147   3.47076613  6.6520224
#   5.90714259  2.71774431  3.9032688   4.92427107  5.06450042  5.05009326
#   3.08616718  4.05165213  5.71386989  5.46118154  5.01125722  4.22071201
#   6.95914829  5.93081698  4.70408983  6.4777666   8.19360968  4.38729808
#   3.24508411  3.78705828  7.31493235  2.92828276  4.78030864  5.53406094
#   3.2188988   3.64773693  3.23785017  6.45292107  6.43932266  4.58203497
#   5.41212117 -0.04494168  3.69188852  6.0957843   4.8777197   5.46346338
#   3.10127789  5.22181439  4.75212608  5.52764068  6.00413843  3.4028061
#   5.38121053  7.33707457  5.18652897  2.20876937  7.67731825  5.69165577
#   6.07394418  6.33632305  4.64636518  5.6884198   4.64316598  5.82448065
#   4.43718395  2.24464176  5.69266689  4.37347876  3.09595831  6.26549244
#   5.20731551  5.42031887  1.64610962  5.73659649  4.16016355  6.6397808
#   2.30587684  9.67622119  6.05774931  5.49438996  2.53975117  5.69331007
#   1.70477484  5.03783145  4.4944125   5.52967605]

# %%
# Ejercicio 21
v1 = np.random.normal(1,0.5,100)
v2 = np.random.logistic(1,0.5,100)
data = {'Normal':v1, 'Log':v2}
df = pd.DataFrame(data)

sns.displot(df, kind = 'kde')
plt.show()

sns.histplot(df)
plt.show()

#dist = ['Normal', 'Logistic']
#plt.figure(figsize = (8, 5))
#sns.kdeplot(data = df, x = 'Normal')
#sns.kdeplot(data = df, x = 'Logistic')
#plt.legend(dist, loc = 'upper left')
#plt.xlabel('values')
#plt.show()
